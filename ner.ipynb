# %%
# import csv as df
import pandas as pd

# import data utf 8
df = pd.read_csv('dataset_spain_sdgs.csv', encoding='ISO-8859-1', sep=",")
df.head()
# Out:
#                                                Title  \
# 0  EL PUERTO DE CARTAGENA ACOGE EL EJERCICIO CLE...
# 1  La Autoridad Portuaria de Cartagena y el Gobie...
# 2  Éxito del IV Congreso Workshop Intervención O...
# 3    FERMÍN ROL TOMA POSESIÓN COMO DIRECTOR GENERAL.
# 4  EL PRESIDENTE DE LA APC RECIBE A REPRESENTANTE...
#
#                                                 Text  Source  \
# 0  Está mañana el puerto de Cartagena ha acogido ...  apc.es
# 1  La Autoridad Portuaria de Cartagena y el Gobie...  apc.es
# 2  La Autoridad Portuaria de Cartagena ha inaugur...  apc.es
# 3  El pasado 26 de septiembre, el Consejo de Admi...  apc.es
# 4  Antonio Sevilla, presidente de la Autoridad Po...  apc.es
#
#                                                Links
# 0  https://www.apc.es/webapc/publicaciones/notici...
# 1  https://www.apc.es/webapc/publicaciones/notici...
# 2  https://www.apc.es/webapc/publicaciones/notici...
# 3  https://www.apc.es/webapc/publicaciones/notici...
# 4  https://www.apc.es/webapc/publicaciones/notici...

# %%
import spacy
nlp = spacy.load("es_core_news_sm")

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'morphologizer', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
# get all unique entities in the dataset and save them to a csv with the label

entities = []
labels = []

for ent in df['Text']:
    doc = nlp(ent)
    for ent in doc.ents:
        entities.append(ent.text)
        labels.append(ent.label_)

# create a dataframe with the entities and labels
entities_df = pd.DataFrame({'entities': entities, 'labels': labels})
entities_df.head()
# Out:
#                                          entities labels
# 0                                       Cartagena    LOC
# 1                            Clean Port Cartagena   MISC
# 2                                    mar de fenol    LOC
# 3                                             Con   MISC
# 4  Plan Interior Marítimo del puerto de Cartagena   MISC

# %%
# filter only unique entities and add a count column
unique_entities = entities_df['entities'].unique()
unique_entities_df = pd.DataFrame({'entities': unique_entities})
unique_entities_df['count'] = 0

# count the number of times each entity appears in the dataset
for ent in entities_df['entities']:
    unique_entities_df.loc[unique_entities_df['entities'] == ent, 'count'] += 1


# sort the dataframe by the count column
unique_entities_df.sort_values(by=['count'], inplace=True, ascending=False)
unique_entities_df.head()
# Out:
#                                  entities  count
# 177                                  UPCT   1052
# 0                               Cartagena    604
# 173  Universidad Politécnica de Cartagena    228
# 121                      Región de Murcia    140
# 61                                 España    124

# %%
# add label column
unique_entities_df['label'] = ''

# add label to each entity
for ent in unique_entities_df['entities']:
    unique_entities_df.loc[unique_entities_df['entities'] == ent, 'label'] = entities_df.loc[entities_df['entities'] == ent, 'labels'].values[0]

# sort by label and then by count
unique_entities_df.sort_values(by=['label', 'count'], inplace=True, ascending=False)

# save the dataframe to a csv
unique_entities_df.to_csv('entities.csv', index=False, encoding='ISO-8859-1')

# %%
from spacy import displacy

displacy.render(nlp(df['Text'][0]), style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Está mañana el puerto de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cartagena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  ha acogido el ejercicio &quot;
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clean Port Cartagena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# &quot;, se trata de un simulacro de incendio en buque con vertido al
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mar de fenol
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Con
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  ello se pretende comprobar el funcionamiento  del
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Plan Interior Marítimo del puerto de Cartagena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PIM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ),  aprobado este
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     año
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  y que da respuesta a episodios de contaminación marina.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     También
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  se han activado el
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Plan de Emergencia Interior
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  (PEI) del puerto de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cartagena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  y, en fase de alerta el
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Plan Marítimo Nacional
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .  El ejercicio ha consistido en la activación de los planes anteriormente citados tras el simulacro de incendio en la máquina principal del buque
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fenol One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  (nombre ficticio) fondeado en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zona II del puerto de Cartagena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , y que está a la espera de asignación  de lugar de atraque. Tras ser controlado el incendio se detecta que el barco vierte una cantidad sin determinar de fenol al mar, se trata de un producto clasificado  toxico y nocivo, que emana vapores que afectan a los ojos.  Tras el incendio y la activación del PEI, se pasa de la
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fase Alerta a la Fase Verde
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  y, posteriormente a la
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fase Azul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  por emergencia en el agua, tal y como se especifica  en el
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Plan de Emergencia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  del puerto de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cartagena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Una vez extinguido el incendio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , se ha pasado de alerta a emergencia por el vertido tóxico.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     También
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  se han activado los
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Planes Locales
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  y
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Territoriales
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  por contaminación marina (
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ayuntamientos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  afectados 
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin:
